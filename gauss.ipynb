# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import pandas as pd
import numpy as np

# %%
X_train_in = pd.read_csv("/kaggle/input/x-train/X_train2.csv", index_col=0)
y_train_in = pd.read_csv("/kaggle/input/y-train/y_train2.csv",index_col=0)
X_val = pd.read_csv("/kaggle/input/x-test/X_test2.csv", index_col=0)
X_test_in = pd.read_csv("/kaggle/input/x-test/X_test2.csv", index_col=0)
#X_test_in, X_val,X_train_in, y_train_in

# %%
X_train_in.rename(columns={'КУРС': 'COURSE', 'СЕМЕСТР': 'SEMESTER', "ГОД":"YEAR", "НАПРАВЛЕНИЕ":"DIRECTION", "АТТЕСТАЦИЯ":"CERTIFICATION", "ДИСЦИПЛИНА":"DISCIPLINE"}, inplace=True)
X_train_in

# %%
X_train_in["COURSE"]=X_train_in["COURSE"].astype("int")
X_train_in['SEMESTER']=X_train_in['SEMESTER'].astype('int')

# %%
#numpy.unique(a, return_index=False, return_inverse=False, return_counts=False, axis=None)
#Функция unique() находит уникальные элементы массива и возвращает их в отсортированном массиве.
DIR=X_train_in["DIRECTION"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (105058):
    z=X_train_in.iloc[i,1]
    x= list(A).index(z)
    X_train_in.iloc[i,1]=x
X_train_in

# %%
DIR=X_train_in["CERTIFICATION"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (105058):
    z=X_train_in.iloc[i,5]
    x= list(A).index(z)
    X_train_in.iloc[i,5]=x
X_train_in

# %%
DIR=X_train_in["DISCIPLINE"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (105058):
    z=X_train_in.iloc[i,6]
    x= list(A).index(z)
    X_train_in.iloc[i,6]=x
X_train_in

# %%
DIR=X_train_in["YEAR"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (105058):
    z=X_train_in.iloc[i,2]
    x= list(A).index(z)
    X_train_in.iloc[i,2]=x
X_train_in

# %%
X_val.rename(columns={'КУРС': 'COURSE', 'СЕМЕСТР': 'SEMESTER', "ГОД":"YEAR", "НАПРАВЛЕНИЕ":"DIRECTION", "АТТЕСТАЦИЯ":"CERTIFICATION", "ДИСЦИПЛИНА":"DISCIPLINE"}, inplace=True)

# %%
X_val["COURSE"]=X_val["COURSE"].astype("int")
X_val['SEMESTER']=X_val['SEMESTER'].astype('int')
X_val

# %%
#numpy.unique(a, return_index=False, return_inverse=False, return_counts=False, axis=None)
#Функция unique() находит уникальные элементы массива и возвращает их в отсортированном массиве.
DIR=X_val["DIRECTION"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_val.iloc[i,1]
    x= list(A).index(z)
    X_val.iloc[i,1]=x
X_val

# %%
DIR=X_val["CERTIFICATION"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_val.iloc[i,5]
    x= list(A).index(z)
    X_val.iloc[i,5]=x
X_val

# %%
DIR=X_val["DISCIPLINE"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_val.iloc[i,6]
    x= list(A).index(z)
    X_val.iloc[i,6]=x
X_val

# %%
DIR=X_val["YEAR"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_val.iloc[i,2]
    x= list(A).index(z)
    X_val.iloc[i,2]=x
X_val

# %%
X_test_in.rename(columns={'КУРС': 'COURSE', 'СЕМЕСТР': 'SEMESTER', "ГОД":"YEAR", "НАПРАВЛЕНИЕ":"DIRECTION", "АТТЕСТАЦИЯ":"CERTIFICATION", "ДИСЦИПЛИНА":"DISCIPLINE"}, inplace=True)
X_test_in

# %%
X_test_in["COURSE"]=X_test_in["COURSE"].astype("int")
X_test_in['SEMESTER']=X_test_in['SEMESTER'].astype('int')

# %%
#numpy.unique(a, return_index=False, return_inverse=False, return_counts=False, axis=None)
#Функция unique() находит уникальные элементы массива и возвращает их в отсортированном массиве.
DIR=X_test_in["DIRECTION"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_test_in.iloc[i,1]
    x= list(A).index(z)
    X_test_in.iloc[i,1]=x
X_test_in

# %%
DIR=X_test_in["CERTIFICATION"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_test_in.iloc[i,5]
    x= list(A).index(z)
    X_test_in.iloc[i,5]=x
X_test_in

# %%
DIR=X_test_in["DISCIPLINE"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_test_in.iloc[i,6]
    x= list(A).index(z)
    X_test_in.iloc[i,6]=x
X_test_in

# %%
DIR=X_test_in["YEAR"]
A,B = np.unique(DIR,return_counts=True)
len(B)
B
len(A)
A
for i in range (26265):
    z=X_test_in.iloc[i,2]
    x= list(A).index(z)
    X_test_in.iloc[i,2]=x
X_test_in

# %%
X_test_in.to_csv("X_test_in.csv")

# %%
X_train_in.to_csv("X_train_in.csv")

# %%
X_val.to_csv("X_val.csv")

# %% [markdown]
# ***КОНЕЦ 1 ЧАСТИ*
# !!! все остальное работает с переделанными таблицами****

# %%
X_train_in = pd.read_csv("/kaggle/input/x-train-in-new/X_train_in.csv", index_col=0)
X_val = pd.read_csv("/kaggle/input/x-val-new/X_val.csv", index_col=0)
X_test_in = pd.read_csv("/kaggle/input/x-test/X_test2.csv", index_col=0)
y_train_in = pd.read_csv("/kaggle/input/y-train/y_train2.csv",index_col=0)

# %%
X_all = X_train_in.append(X_val, ignore_index=True)

# %%
X_train_in["mark"]=y_train_in["mark"]

# %%
stud_mean_mark = X_train_in.groupby("STD_ID").mean()["mark"]
X_train_in.loc[:,"stud_mean"] = X_train_in.loc[:,"STD_ID"].map(stud_mean_mark)

# %%
X_train_in.loc[:,"stud_std"] = X_train_in.loc[:,"STD_ID"].map(stud_std_mark)

# %%
X_train_in.loc[:,"stud_mean"]

# %%
X_train_in.loc[:,"stud_std"]

# %%
X_val.loc[:,"stud_mean"] = X_val.loc[:,"STD_ID"].map(stud_mean_mark)

# %%
X_val.loc[:,"stud_std"] = X_val.loc[:,"STD_ID"].map(stud_std_mark)

# %%
from sklearn.model_selection import train_test_split

# %%
#train_col = ["STD_ID","DIRECTION","YEAR",'COURSE','SEMESTER',"CERTIFICATION","DISCIPLINE","stud_mean", "stud_std"]
train_col = ["STD_ID","DISCIPLINE","stud_mean", "stud_std"]
#X_train["STD_ID"]= X_train["STD_ID"].astype(int)
#X_test["STD_ID"]= X_test["STD_ID"].astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_in[train_col],X_train_in["mark"], shuffle=True, test_size=0.3)

# %%
y_test.shape, y_train.shape

# %%
X_train.fillna(X_train.min())

# %%
#ОЧЕНЬ надо
#чтобы не было проблем NAN при обучении
from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer()
X_train = my_imputer.fit_transform(X_train)
#y_train = my_imputer.fit_transform(y_train)

# %%
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_train
predicted = model.predict(X_train)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# %%
y_pred = pd.read_csv("/kaggle/input/sample-submission/sample_submission2.csv",index_col=0)
y_pred

# %%
#ГАУСС
X_val['stud_mean']=X_val['stud_mean']*10
X_val=X_val.fillna(X_val.mean())

X_val['stud_mean']=round(X_val['stud_mean'])

X_val


X_val['stud_mean']=X_val['stud_mean'].astype('int')


y_pred = pd.read_csv("/kaggle/input/sample-submission/sample_submission2.csv",index_col=0)
y_pred["mark"]=y_pred["mark"].astype("int")
y_pred


y_pred.to_csv("baseline_submission_B.csv")
